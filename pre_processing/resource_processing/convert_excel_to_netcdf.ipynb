# %%
import pandas as pd
import xarray as xr

# %%
# path to excel file with hourly renewable energy data
excel_file = "demo_excel_to_netcdf.xlsx"
xl_data = pd.read_excel(excel_file, sheet_name=None)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[2], line 3
#       1 # path to excel file with hourly renewable energy data
#       2 excel_file = "demo_excel_to_netcdf.xlsx"
# ----> 3 xl_data = pd.read_excel(excel_file, sheet_name=None)
#
# File ~/anaconda3/envs/pypsa-rsa/lib/python3.12/site-packages/pandas/io/excel/_base.py:495, in read_excel(io, sheet_name, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, parse_dates, date_parser, date_format, thousands, decimal, comment, skipfooter, storage_options, dtype_backend, engine_kwargs)
#     493 if not isinstance(io, ExcelFile):
#     494     should_close = True
# --> 495     io = ExcelFile(
#     496         io,
#     497         storage_options=storage_options,
#     498         engine=engine,
# ...

# %%
# check if exists else create empty xarray dataset re_profiles = xr.open_dataset("renewable_profiles_updated.nc")
try:
    re_profiles = xr.open_dataarray("renewable_profiles_updated.nc")
except:
    print("No existing NetCDF file found. Creating empty dataset.")
    re_profiles = xr.Dataset()
# Out:
# No existing NetCDF file found. Creating empty dataset.

# %%
f"{carrier}_fixed_{config['resource_profiles']['datasets'][carrier]}"
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 f"{carrier}_fixed_{config['resource_profiles']['datasets'][carrier]}"
#
# NameError: name 'carrier' is not defined

# %%
re_profiles = xr.open_dataarray("renewable_profiles_updated.nc", group="solar_pv_fixed_sarah")

# %%
re_profiles
# Out:
# <xarray.DataArray (time: 52584, plant: 64, param: 2)> Size: 54MB
# [6730752 values with dtype=float64]
# Coordinates:
#   * time     (time) datetime64[ns] 421kB 2017-01-01 ... 2022-12-31T23:00:00
#   * plant    (plant) <U15 4kB 'Aries' 'De_Aar' ... 'Doornhoek' 'Ngonyama'
#   * param    (param) <U5 40B 'power' 'pu'
